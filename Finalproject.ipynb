# %%
import pandas as pd
df=pd.read_csv("train.csv")

api_key="e5eec44335d5436b89247f909654bff2"
df
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0        id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1        id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2        id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3        id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4        id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# ...            ...        ...                  ...                  ...
# 1458639  id2376096          2  2016-04-08 13:31:04  2016-04-08 13:44:02
# 1458640  id1049543          1  2016-01-10 07:35:15  2016-01-10 07:46:10
# 1458641  id2304944          2  2016-04-22 06:57:41  2016-04-22 07:10:25
# 1458642  id2714485          1  2016-01-05 15:56:26  2016-01-05 16:02:39
# 1458643  id1209952          1  2016-04-05 14:44:25  2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# ...

# %%
xx=df[:50000]

# %%
import requests
from requests.structures import CaseInsensitiveDict
lat_start=xx['pickup_latitude']
lon_start=xx['pickup_longitude']
lat_fin=xx['dropoff_latitude']
lon_fin=xx['dropoff_longitude']
st1=[]
st2=[]
city1=[]
city2=[]
for elem in range(0, len(lat_start)):
    url1 = f"https://api.geoapify.com/v1/geocode/reverse?lat={lat_start}&lon={lon_start}&format=json&apiKey={api_key}"
    url2 = f"https://api.geoapify.com/v1/geocode/reverse?lat={lat_fin}&lon={lon_fin}&format=json&apiKey={api_key}"
    headers = CaseInsensitiveDict()
    headers["Accept"] = "application/json"
    resp1 = requests.get(url1, headers=headers)
    resp2 = requests.get(url2, headers=headers)
    res1=resp1.json().get('results')
    st1.append(res1[0].get('state'))
    city1.append(res1[0].get('city')
    res2=resp2.json().get('results')
    st2.append(res2[0].get('state'))
    city2.append(res2[0].get('city')
# Out:
#   File "/tmp/ipykernel_17/4076306898.py", line 21
#     res2=resp2.json().get('results')
#        ^
# SyntaxError: invalid syntax

# %%
import requests
lat_start="40.767937"
lon_start="-73.982155"
url = f"https://api.geoapify.com/v1/geocode/reverse?lat={lat_start}&lon={lon_start}&format=json&apiKey={api_key}"


resp = requests.get(url)
street= resp.json()['results'][0]['street']
suburb= resp.json()['results'][0]['suburb']
city = resp.json()['results'][0]['city']
state = resp.json()['results'][0].keys()
state
# Out:
# dict_keys(['datasource', 'name', 'country', 'country_code', 'state', 'county', 'city', 'postcode', 'district', 'suburb', 'street', 'lon', 'lat', 'state_code', 'distance', 'result_type', 'formatted', 'address_line1', 'address_line2', 'category', 'timezone', 'rank', 'place_id', 'bbox'])

# %% [markdown]
# # DA QUI

# %%
prova = df[:500].copy()

# %%
def extract_info(data):
    longitude = data['pickup_longitude']
    latitude = data['pickup_latitude']
    
    url = f"https://api.geoapify.com/v1/geocode/reverse?lat={latitude}&lon={longitude}&format=json&apiKey={api_key}"
    resp = requests.get(url)
    
    
#     if 'street' in resp.json()['results'][0].keys():
        
#          street= resp.json()['results'][0]['street']
#     else:
#          street = resp.json()['results'][0]['road']
        
#     suburb= resp.json()['results'][0]['suburb']
#     city = resp.json()['results'][0]['city']
#     state = resp.json()['results'][0]['state']
#     return (street,suburb,city,state)
    
    formatted= resp.json()['results'][0]['formatted']
    return formatted


prova['location_info'] = prova.apply(extract_info, axis=1)

# %%
prova
# Out:
#             id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0    id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1    id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2    id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3    id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4    id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# ..         ...        ...                  ...                  ...
# 495  id0194198          2  2016-05-15 14:44:09  2016-05-15 15:29:08
# 496  id0260905          1  2016-01-13 21:06:29  2016-01-13 21:18:20
# 497  id0398807          2  2016-02-23 14:50:40  2016-02-23 15:07:24
# 498  id1428415          1  2016-02-14 20:13:17  2016-02-14 20:28:14
# 499  id3920713          2  2016-01-16 17:56:52  2016-01-16 18:03:34
#
#      passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %%
#prova['location_info'] = prova.apply(extract_info, axis=1)
#prova[['street', 'suburb', 'city', 'state']] = pd.DataFrame(prova['location_info'].tolist(), index=prova.index)

# %%
prova
